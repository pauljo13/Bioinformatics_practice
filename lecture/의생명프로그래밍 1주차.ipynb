# %%
def print_hi(name):
  print(f'Hi {name}')

print_hi("jo")
# Out:
# Hi jo

# %%
import math

# %%
# Quiz
print("몫 :",math.log2(128) // 3)
print("나머지 :", math.log2(128) % 3)
# Out:
# 몫 : 2.0
# 나머지 : 1.0

# %%
# 변수 지정
# '=' : 변수를 지정

a = 1
b = 2
a + b
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
b = float(a)
type(b)
# Out:
# float

# %%
a, b, c = 1, 2, 3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
# Quiz
a,b = math.log2(128), math.log2(256)
c = a*b
print(c)
# Out:
# 56.0

# %%
a = 1
a == 1
# Out:
# True

# %%
a = b =2
a == b
# Out:
# True

# %%
c = 3
a == b
# Out:
# True

# %%
a == b == c
# Out:
# False

# %%
b == c
# Out:
# False

# %%
a == b != c
# Out:
# True

# %%
# Quiz
2**3 == 8
# Out:
# True

# %%
a = 1
a = a + 2
print(a)

a = 1
a += 2
print(a)

a -= 1
print(a)

a *= 3
print(a)

a /= 3
print(a)
# Out:
# 3
# 3
# 2
# 6
# 2.0

# %%
# String

a = 'python'
print(a)

a = '1'
b = '2'
print(a+b)
# Out:
# python
# 12

# %%
print("I love 'python'")
print('I love "python"')
# Out:
# I love 'python'
# I love "python"

# %%
a = 'i need to study Python'
len(a)
# Out:
# 22

# %%
a = "Hello, world!"
print(len(a))
if len(a) % 2 == 0:
  print("짝수")
else:
  print("홀수")
# Out:
# 13
# 홀수

# %%
a = 'i need to study Python'
print(len(a))
print(a[0])
print(a[21])

print(a[-1])
print(a[-22])
# Out:
# 22
# i
# n
# n
# i

# %%
print(a[16:21])
print(a[16:22:2])
print(a[::-1])

print(a[16:len(a)]) # 자주사용
print(a[16:])
print(a[16:-1])

print(a[0:9])
print(a[:9])
# Out:
# Pytho
# Pto
# nohtyP yduts ot deen i
# Python
# Python
# Pytho
# i need to
# i need to

# %%
perfix = a[:10]
verb = a[10:16]
noun = a[16:]
print(perfix)
print(verb)
print(noun)

print(perfix + verb + noun)
# Out:
# i need to
# study
# Python
# i need to study Python

# %%
# Quiz
a = "DNA nucleotides consist of 'ATCG'"

print(a[27:])
print(a[28:-1])
print(a[::-1][1:5])
# Out:
# 'ATCG'
# ATCG
# GCTA

# %%
obj = "java"
print(perfix + verb + obj)
# Out:
# i need to study java

# %%
py = 'Python'
ja = 'Java'
print('i need to study %s'%py)
print('i need to study %s'%ja)
print('i need to study %d'% 3)
print('i need to study %f'% 2.7)
print('i need to study %.1f'% 2.777)
print('i need to study %5.1f'% 2.777)
print('i need to study %2.1f'% 2.7)
# Out:
# i need to study Python
# i need to study Java
# i need to study 3
# i need to study 2.700000
# i need to study 2.8
# i need to study   2.8
# i need to study 2.7

# %%
# Quiz
"The ratio of a circle`s circumference to its diameter is called %s, and the value of %s is %.2f" %('pi','pi',math.pi)
# Out:
# 'The ratio of a circle`s circumference to its diameter is called pi, and the value of pi is 3.14'

# %%
def print_hi(name):
  print(f'Hi, {name}')

print_hi("python")
# Out:
# Hi, python

# %%
lang = 'python'
ver = 3.8
print(f'I need to study {lang}{ver}')
print(f'I need to study {lang}{ver:.2f}')
print(f'I need to study {lang}{ver+1}')
# Out:
# I need to study python3.8
# I need to study python3.80
# I need to study python4.8

# %%
# Quiz
pi ="pi"
pinum = math.pi
print(f'The ratio of a circle`s circumference to its diameter is called {pi}, and the value of {pi} is {pinum:.2f}')
# Out:
# The ratio of a circle`s circumference to its diameter is called pi, and the value of pi is 3.14

# %%
print(a)
a = "How many white-spaces in this sentence?"
print(a.count(" "))
print(a.count("h"))
# Out:
# DNA nucleotides consist of 'ATCG'
# 5
# 2

# %%
seq = "ATCGATCGAAAA"
print(seq.count("T"))
print(seq.find("T"))
print(seq.find("AAA"))
print(seq.find("N"))
print(seq.index("A"))
print(seq.index("N"))
# Out:
# 2
# 1
# 8
# -1
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2098121952.py in <cell line: 0>()
#       5 print(seq.find("N"))
#       6 print(seq.index("A"))
# ----> 7 print(seq.index("N"))
#
# ValueError: substring not found

# %%
# Quiz
seq2 = "AATCAAAACCGAATTTTT"
for i in ["A", "T", "C", "G"]:
  print(f"{i} : {seq2.count(i)}")
  print(f"{i} : {seq2.count(i) / len(seq2):.2f}")
# Out:
# A : 8
# A : 0.44
# T : 6
# T : 0.33
# C : 3
# C : 0.17
# G : 1
# G : 0.06

# %%
seq
'/t'.join(seq)
' '.join(seq)

seq.split('C')
# Out:
# ['AT', 'GAT', 'GAAAA']

# %%
a = f'{"ATCG":^10}' # 총 길이는 10이고 중앙정렬해라
a
# Out:
# '   ATCG   '

# %%
a.strip()
# Out:
# 'ATCG'

# %%
a.lstrip()
# Out:
# 'ATCG   '

# %%
a.rstrip()
# Out:
# '   ATCG'

# %%
a = f'{"ATCG":!^10}'
a
# Out:
# '!!!ATCG!!!'

# %%
a.strip("!")
# Out:
# 'ATCG'

# %%
a.replace("!","?")
# Out:
# '???ATCG???'

# %%
# Quiz
"ATCGATCG"
# Out:
# 'ATCGATCG'

# %%
seq.split('\t')
# Out:
# ['ATCGATCGAAAA']

# %%
# Quiz
a = ",".join('ATCG')
print(a)
a.split(',')
# Out:
# A,T,C,G
# ['A', 'T', 'C', 'G']
